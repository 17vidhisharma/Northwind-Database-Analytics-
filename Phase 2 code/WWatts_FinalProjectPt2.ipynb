# %%
# Importing the SQLite package
import sqlite3
# Importing error checking 
from sqlite3 import Error

import pandas as pd

# %%
# Establish database connection
connection = sqlite3.connect("northwind.db")

# %%
def execute_read_query(connection,query):
    cursor = connection.cursor()
    result = None 
    try:
        cursor.execute(query)
        result = cursor.fetchall()
        return  result
    except Error as e:
        print(f"The Error '{e}' occurred.")

# %%
cursor.execute('''with cte as (SELECT ContactName FROM Customers
        WHERE Address < 20)
select * from cte
''')
result = cursor.fetchall()
result
# Out:
# [('Thomas Hardy',),
#  ('Laurence Lebihan',),
#  ('Martine Rancé',),
#  ('Annette Roulet',),
#  ('Yoshi Tannamuri',),
#  ('John Steel',),
#  ('Jose Pavarotti',),
#  ('Mary Saveley',)]

# %%
average_order_value = '''
    SELECT c.CustomerID,
       c.CompanyName,
       ROUND(AVG(ot.OrderTotal), 2) AS AverageOrderValue
  FROM Customers AS c
       JOIN
       (
           SELECT o.CustomerID,
                  SUM(od.UnitPrice * od.Quantity * (1 - od.Discount) ) AS OrderTotal
             FROM [Order Details] AS od
                  JOIN
                  Orders AS o ON od.OrderID = o.OrderID
            GROUP BY o.OrderID
       )
       AS ot ON c.CustomerID = ot.CustomerID
 GROUP BY c.CustomerID,
          c.CompanyName
 ORDER BY AverageOrderValue DESC;
 '''
first_query = execute_read_query(connection, average_order_value)

# %%
first_query[0:3]
# Out:
# [('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 30448.65),
#  ('PICCO', 'Piccolo und mehr', 30318.79),
#  ('Val2 ', 'IT', 30316.21)]

# %%
first_query_df = pd.DataFrame(
    data = first_query,
    columns = ['CustomerID', 'CompanyName', 'AverageOrderValue']
)
first_query_df
# Out:
#    CustomerID                           CompanyName  AverageOrderValue
# 0       FISSA  FISSA Fabrica Inter. Salchichas S.A.           30448.65
# 1       PICCO                      Piccolo und mehr           30318.79
# 2       Val2                                     IT           30316.21
# 3       MORGK                Morgenstern Gesundkost           30051.07
# 4       PERIC             Pericles Comidas clásicas           30010.78
# ..        ...                                   ...                ...
# 88      LEHMS                   Lehmanns Marktstand           25205.69
# 89      QUEDE                           Que Delícia           25196.45
# 90      ALFKI                   Alfreds Futterkiste           24328.01
# 91      ERNSH                          Ernst Handel           24288.01
# 92      SAVEA                    Save-a-lot Markets           23789.82
#
# [93 rows x 3 columns]

# %%
with pd.option_context('display.max_rows', None):
    print(first_query_df)
# Out:
#    CustomerID                           CompanyName  AverageOrderValue
# 0       FISSA  FISSA Fabrica Inter. Salchichas S.A.           30448.65
# 1       PICCO                      Piccolo und mehr           30318.79
# 2       Val2                                     IT           30316.21
# 3       MORGK                Morgenstern Gesundkost           30051.07
# 4       PERIC             Pericles Comidas clásicas           30010.78
# 5       PARIS                     Paris spécialités           29850.85
# 6       THECR                       The Cracker Box           29748.41
# 7       MAISD                          Maison Dewey           29727.34
# 8       BOLID             Bólido Comidas preparadas           29659.69
# 9       SIMOB                         Simons bistro           29611.76
# 10      LAZYK                  Lazy K Kountry Store           29593.22
# 11      LACOR                  La corne d'abondance           29550.21
# 12      SANTG                         Santé Gourmet           29504.72
# 13      THEBI                        The Big Cheese           29456.47
# 14      BSBEV                         B's Beverages           29305.31
# 15      FAMIA                    Familia Arquibaldo           29141.55
# 16      VAFFE                          Vaffeljernet           28894.04
# 17      WELLI                Wellington Importadora           28831.93
# 18      HUNGC            Hungry Coyote Import Store           28777.90
# 19      RANCH                         Rancho grande           28655.21
# 20      LETSS                     Let's Stop N Shop           28597.90
# 21      BLONP              Blondesddsl père et fils           28521.08
# 22      ANATR    Ana Trujillo Emparedados y helados           28381.32
# 23      HANAR                         Hanari Carnes           28321.90
# 24      BONAP                              Bon app'           28297.52
# 25      SEVES                    Seven Seas Imports           28272.85
# 26      WARTH                        Wartian Herkku           28237.15
# 27      FOLIG                     Folies gourmandes           28233.35
# 28      SPECD                  Spécialités du monde           28182.29
# 29      VICTE                  Victuailles en stock           28067.48
# 30      VALON                                    IT           27983.49
# 31      COMMI                      Comércio Mineiro           27891.00
# 32      MEREP                        Mère Paillarde           27871.31
# 33      OTTIK                    Ottilies Käseladen           27747.02
# 34      EASTC                    Eastern Connection           27745.32
# 35      WANDK                     Die Wandernde Kuh           27741.58
# 36      FRANR                   France restauration           27704.81
# 37      GREAL               Great Lakes Food Market           27688.19
# 38      GROSR                  GROSELLA-Restaurante           27672.85
# 39      RICSU                    Richter Supermarkt           27624.17
# 40      MAGAA          Magazzini Alimentari Riuniti           27622.34
# 41      GALED                Galería del gastrónomo           27609.36
# 42      GOURL                   Gourmet Lanchonetes           27486.68
# 43      CACTU            Cactus Comidas para llevar           27472.49
# 44      WILMK                           Wilman Kala           27429.51
# 45      VINET             Vins et alcools Chevalier           27419.08
# 46      CONSH                 Consolidated Holdings           27395.60
# 47      FRANK                        Frankenversand           27376.14
# 48      BOTTM                 Bottom-Dollar Markets           27374.07
# 49      QUEEN                         Queen Cozinha           27348.87
# 50      TRAIH     Trail's Head Gourmet Provisioners           27336.43
# 51      OLDWO                Old World Delicatessen           27325.33
# 52      SUPRD                      Suprêmes délices           27277.70
# 53      TOMSP                    Toms Spezialitäten           27270.56
# 54      CHOPS                     Chop-suey Chinese           27263.16
# 55      AROUT                       Around the Horn           27255.27
# 56      RICAR                    Ricardo Adocicados           27214.37
# 57      HILAA                      HILARION-Abastos           27198.45
# 58      PRINI                Princesa Isabel Vinhos           27183.85
# 59      ROMEY                      Romero y tomillo           27174.83
# 60      DRACD              Drachenblut Delikatessen           27155.05
# 61      BERGS                    Berglunds snabbköp           27153.92
# 62      TRADH                Tradição Hipermercados           27059.00
# 63      QUICK                            QUICK-Stop           26988.94
# 64      RATTC            Rattlesnake Canyon Grocery           26941.47
# 65      BLAUS               Blauer See Delikatessen           26900.11
# 66      FRANS                        Franchi S.p.A.           26867.29
# 67      TORTU                   Tortuga Restaurante           26792.30
# 68      LILAS                     LILA-Supermercado           26785.41
# 69      WOLZA                        Wolski  Zajazd           26770.99
# 70      GODOS                   Godos Cocina Típica           26721.38
# 71      LAUGB         Laughing Bacchus Wine Cellars           26624.91
# 72      SPLIR                 Split Rail Beer & Ale           26623.38
# 73      DUMON                       Du monde entier           26476.30
# 74      CENTC            Centro comercial Moctezuma           26472.67
# 75      ANTON               Antonio Moreno Taquería           26452.60
# 76      FURIB        Furia Bacalhau e Frutos do Mar           26442.89
# 77      ISLAT                        Island Trading           26408.37
# 78      REGGC                    Reggiani Caseifici           26395.26
# 79      OCEAN                Océano Atlántico Ltda.           26357.66
# 80      KOENE                       Königlich Essen           26108.33
# 81      HUNGO          Hungry Owl All-Night Grocers           26001.55
# 82      NORTS                           North/South           25933.79
# 83      LONEP              Lonesome Pine Restaurant           25896.71
# 84      FOLKO                        Folk och fä HB           25521.72
# 85      WHITC                  White Clover Markets           25479.28
# 86      LINOD                      LINO-Delicateses           25407.40
# 87      LAMAI                      La maison d'Asie           25274.01
# 88      LEHMS                   Lehmanns Marktstand           25205.69
# 89      QUEDE                           Que Delícia           25196.45
# 90      ALFKI                   Alfreds Futterkiste           24328.01
# 91      ERNSH                          Ernst Handel           24288.01
# 92      SAVEA                    Save-a-lot Markets           23789.82

# %%
customer_ranking = '''
    WITH CustomerAverages AS (
  SELECT
    o.CustomerID,
    SUM(od.UnitPrice * od.Quantity * (1 - od.Discount)) AS OrderTotal
  FROM Orders o
  JOIN [Order Details] od ON o.OrderID = od.OrderID
  GROUP BY o.OrderID
),
Ranked AS (
  SELECT
    c.CustomerID,
    c.CompanyName,
    ROUND(AVG(ca.OrderTotal), 2) AS AvgOrderValue,
    RANK() OVER (ORDER BY AVG(ca.OrderTotal) DESC) AS Rank
  FROM Customers c
  JOIN CustomerAverages ca ON c.CustomerID = ca.CustomerID
  GROUP BY c.CustomerID, c.CompanyName
)
SELECT *
FROM Ranked
WHERE Rank IN (2, 3, 5, 8, 12, 15, 17)
ORDER BY Rank;
'''
second_query = execute_read_query(connection, customer_ranking)
second_query[0:3]
# Out:
# [('PICCO', 'Piccolo und mehr', 30318.79, 2),
#  ('Val2 ', 'IT', 30316.21, 3),
#  ('PERIC', 'Pericles Comidas clásicas', 30010.78, 5)]

# %%
second_query_df = pd.DataFrame(
    data = second_query,
    columns = ['CustomerID', 'CompanyName', 'AvgOrderValue', 'Rank']
)
second_query_df
# Out:
#   CustomerID                CompanyName  AvgOrderValue  Rank
# 0      PICCO           Piccolo und mehr       30318.79     2
# 1      Val2                          IT       30316.21     3
# 2      PERIC  Pericles Comidas clásicas       30010.78     5
# 3      MAISD               Maison Dewey       29727.34     8
# 4      LACOR       La corne d'abondance       29550.21    12
# 5      BSBEV              B's Beverages       29305.31    15
# 6      VAFFE               Vaffeljernet       28894.04    17

# %%
# Query: compute total for each order
order_totals_query = """
SELECT
    o.OrderID,
    o.CustomerID,
    o.OrderDate,
    SUM(od.UnitPrice * od.Quantity * (1 - od.Discount)) AS OrderTotal
FROM Orders o
JOIN [Order Details] od ON o.OrderID = od.OrderID
GROUP BY o.OrderID, o.CustomerID, o.OrderDate
"""
order_totals = execute_read_query(connection, order_totals_query)

# %%
order_totals_df = pd.DataFrame(
    data = order_totals,
    columns = ['OrderID', 'CustomerID', 'OrderDate', 'OrderTotal']
)
order_totals_df.head(3)
# Out:
#    OrderID CustomerID   OrderDate  OrderTotal
# 0    10248      VINET  2016-07-04       440.0
# 1    10249      TOMSP  2016-07-05      1863.4
# 2    10250      HANAR  2016-07-08      1552.6

# %%
# Query: aggregate customer orders with counts, totals, averages, and ranks
customer_agg_query = """
WITH OrderTotals AS (
    SELECT
        o.OrderID,
        o.CustomerID,
        SUM(od.UnitPrice * od.Quantity * (1 - od.Discount)) AS OrderTotal
    FROM Orders o
    JOIN [Order Details] od ON o.OrderID = od.OrderID
    GROUP BY o.OrderID, o.CustomerID
)
SELECT
    c.CustomerID,
    c.CompanyName,
    COUNT(ot.OrderID) AS OrderCount,
    SUM(ot.OrderTotal) AS TotalRevenue,
    AVG(ot.OrderTotal) AS AvgOrderValue,
    RANK() OVER (ORDER BY AVG(ot.OrderTotal) DESC) AS AOV_Rank
FROM Customers c
JOIN OrderTotals ot ON ot.CustomerID = c.CustomerID
GROUP BY c.CustomerID, c.CompanyName
"""
customer_agg = execute_read_query(connection, customer_agg_query)

# %%
customer_agg_df = pd.DataFrame(
    data = customer_agg,
    columns = ['CustomerID', 'CompanyName', 'OrderCount', 'TotalRevenue', 'AvgOrderValue', 'AOV_Rank']
)
customer_agg_df.head(20)
# Out:
#    CustomerID                           CompanyName  OrderCount  TotalRevenue  \
# 0       FISSA  FISSA Fabrica Inter. Salchichas S.A.         155  4.719540e+06
# 1       PICCO                      Piccolo und mehr         177  5.366426e+06
# 2       Val2                                     IT         159  4.820277e+06
# 3       MORGK                Morgenstern Gesundkost         178  5.349090e+06
# 4       PERIC             Pericles Comidas clásicas         169  5.071823e+06
# 5       PARIS                     Paris spécialités         161  4.805988e+06
# 6       THECR                       The Cracker Box         168  4.997732e+06
# 7       MAISD                          Maison Dewey         162  4.815829e+06
# 8       BOLID             Bólido Comidas preparadas         182  5.398064e+06
# 9       SIMOB                         Simons bistro         161  4.767494e+06
# 10      LAZYK                  Lazy K Kountry Store         167  4.942068e+06
# 11      LACOR                  La corne d'abondance         155  4.580282e+06
# 12      SANTG                         Santé Gourmet         159  4.691251e+06
# 13      THEBI                        The Big Cheese         164  4.830861e+06
# 14      BSBEV                         B's Beverages         210  6.154115e+06
# 15      FAMIA                    Familia Arquibaldo         168  4.895780e+06
# 16      VAFFE                          Vaffeljernet         171  4.940881e+06
# 17      WELLI                Wellington Importadora         185  5.333908e+06
# 18      HUNGC            Hungry Coyote Import Store         198  5.698024e+06
# 19      RANCH                         Rancho grande         194  5.559110e+06
#
#     AvgOrderValue  AOV_Rank
# 0    30448.646452         1
# 1    30318.792486         2
# 2    30316.205535         3
# 3    30051.065112         4
# 4    30010.784201         5
# 5    29850.854969         6
# 6    29748.407202         7
# 7    29727.341512         8
# 8    29659.694725         9
# 9    29611.763587        10
# 10   29593.218922        11
# 11   29550.205613        12
# 12   29504.721006        13
# 13   29456.469390        14
# 14   29305.311143        15
# 15   29141.550119        16
# 16   28894.039678        17
# 17   28831.933459        18
# 18   28777.897323        19
# 19   28655.206598        20

# %%
# Top 10 Customers by Average Order Value
customer_agg_df[['CustomerID', 'CompanyName', 'OrderCount','TotalRevenue', 'AvgOrderValue', 'AOV_Rank']].sort_values("AvgOrderValue", ascending = False).head(10)
# Out:
#   CustomerID                           CompanyName  OrderCount  TotalRevenue  \
# 0      FISSA  FISSA Fabrica Inter. Salchichas S.A.         155  4.719540e+06
# 1      PICCO                      Piccolo und mehr         177  5.366426e+06
# 2      Val2                                     IT         159  4.820277e+06
# 3      MORGK                Morgenstern Gesundkost         178  5.349090e+06
# 4      PERIC             Pericles Comidas clásicas         169  5.071823e+06
# 5      PARIS                     Paris spécialités         161  4.805988e+06
# 6      THECR                       The Cracker Box         168  4.997732e+06
# 7      MAISD                          Maison Dewey         162  4.815829e+06
# 8      BOLID             Bólido Comidas preparadas         182  5.398064e+06
# 9      SIMOB                         Simons bistro         161  4.767494e+06
#
#    AvgOrderValue  AOV_Rank
# 0   30448.646452         1
# 1   30318.792486         2
# 2   30316.205535         3
# 3   30051.065112         4
# 4   30010.784201         5
# 5   29850.854969         6
# 6   29748.407202         7
# 7   29727.341512         8
# 8   29659.694725         9
# 9   29611.763587        10

# %%
# Top 10 Customers by Total Revenue
customer_agg_df[['CustomerID', 'CompanyName', 'OrderCount', 'TotalRevenue', 'AvgOrderValue', 'AOV_Rank']].sort_values("TotalRevenue", ascending = False).head(10)
# Out:
#    CustomerID                         CompanyName  OrderCount  TotalRevenue  \
# 14      BSBEV                       B's Beverages         210  6.154115e+06
# 18      HUNGC          Hungry Coyote Import Store         198  5.698024e+06
# 19      RANCH                       Rancho grande         194  5.559110e+06
# 42      GOURL                 Gourmet Lanchonetes         202  5.552310e+06
# 22      ANATR  Ana Trujillo Emparedados y helados         195  5.534357e+06
# 56      RICAR                  Ricardo Adocicados         203  5.524517e+06
# 27      FOLIG                   Folies gourmandes         195  5.505503e+06
# 20      LETSS                   Let's Stop N Shop         191  5.462198e+06
# 68      LILAS                   LILA-Supermercado         203  5.437438e+06
# 58      PRINI              Princesa Isabel Vinhos         200  5.436771e+06
#
#     AvgOrderValue  AOV_Rank
# 14   29305.311143        15
# 18   28777.897323        19
# 19   28655.206598        20
# 42   27486.682203        43
# 22   28381.316154        23
# 56   27214.370985        57
# 27   28233.347949        28
# 20   28597.895406        21
# 68   26785.410542        69
# 58   27183.852750        59

# %%
# Top 10 Customers by Order Count
customer_agg_df[['CustomerID', 'CompanyName', 'OrderCount', 'TotalRevenue', 'AvgOrderValue', 'AOV_Rank']].sort_values("OrderCount", ascending = False).head(10)
# Out:
#    CustomerID                         CompanyName  OrderCount  TotalRevenue  \
# 14      BSBEV                       B's Beverages         210   6154115.340
# 56      RICAR                  Ricardo Adocicados         203   5524517.310
# 68      LILAS                   LILA-Supermercado         203   5437438.340
# 42      GOURL                 Gourmet Lanchonetes         202   5552309.805
# 58      PRINI              Princesa Isabel Vinhos         200   5436770.550
# 18      HUNGC          Hungry Coyote Import Store         198   5698023.670
# 67      TORTU                 Tortuga Restaurante         197   5278083.970
# 22      ANATR  Ana Trujillo Emparedados y helados         195   5534356.650
# 27      FOLIG                   Folies gourmandes         195   5505502.850
# 19      RANCH                       Rancho grande         194   5559110.080
#
#     AvgOrderValue  AOV_Rank
# 14   29305.311143        15
# 56   27214.370985        57
# 68   26785.410542        69
# 42   27486.682203        43
# 58   27183.852750        59
# 18   28777.897323        19
# 67   26792.304416        68
# 22   28381.316154        23
# 27   28233.347949        28
# 19   28655.206598        20

# %%
# Desired ranks
target_ranks = [2, 3, 5, 8, 12, 15, 17]

# Filter rows and create a new DataFrame
selected_customers = customer_agg_df[customer_agg_df["AOV_Rank"].isin(target_ranks)].copy()

# Sort rows by AOV_Rank
selected_customers = selected_customers.sort_values("AOV_Rank")
selected_customers
# Out:
#    CustomerID                CompanyName  OrderCount  TotalRevenue  \
# 1       PICCO           Piccolo und mehr         177   5366426.270
# 2       Val2                          IT         159   4820276.680
# 4       PERIC  Pericles Comidas clásicas         169   5071822.530
# 7       MAISD               Maison Dewey         162   4815829.325
# 11      LACOR       La corne d'abondance         155   4580281.870
# 14      BSBEV              B's Beverages         210   6154115.340
# 16      VAFFE               Vaffeljernet         171   4940880.785
#
#     AvgOrderValue  AOV_Rank
# 1    30318.792486         2
# 2    30316.205535         3
# 4    30010.784201         5
# 7    29727.341512         8
# 11   29550.205613        12
# 14   29305.311143        15
# 16   28894.039678        17
